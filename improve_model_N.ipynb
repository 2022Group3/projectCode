# %% [markdown]
# <a href="https://colab.research.google.com/github/2022Group3/projectCode/blob/main/improve_model_N.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
from matplotlib import pyplot
# from keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from tensorflow.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
from keras.layers import BatchNormalization
import numpy as np
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load train and test dataset
def extract_zip():
	# load dataset
  myfile=np.load(r"drive/MyDrive/data_modified.npz")
  data_npz = dict(zip(("{}".format(k) for k in myfile), (myfile[k] for k in myfile)))
	# one hot encode target values
	# trainY = to_categorical(trainY)
	# testY = to_categorical(testY)
  return data_npz['train'], data_npz['ytrain'], data_npz['validation'], data_npz['yvalidation'], data_npz['test'], data_npz['ytest']

# %%
def load_dataset():
  trainX, trainY, validationX, vlidationY, testX, testY = extract_zip()
  return trainX, to_categorical(trainY), validationX, to_categorical(vlidationY), testX, to_categorical(testY)

# %%
trainX, trainY, validationX, vlidationY, testX, testY = load_dataset()
# print(f'trainx= {trainX} , trainy= {trainY}')

# %%
# scale pixels
def prep_pixels(train, validation, test):
	# convert from integers to floats
	train_norm = train.astype('float32')
	validation_norm = validation.astype('float32')
	test_norm = test.astype('float32')
	# normalize to range 0-1
	train_norm = train_norm / 255.0
	validation_norm = validation_norm / 255.0
	test_norm = test_norm / 255.0
	# return normalized images
	return train_norm,validation_norm, test_norm

# %%
# define cnn model
# VGG with 1 block

def define_model1():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(16, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
	# plot loss
	pyplot.subplot(211)
	pyplot.title('Cross Entropy Loss')
	pyplot.plot(history.history['loss'], color='blue', label='train')
	pyplot.plot(history.history['val_loss'], color='orange', label='validation')
	# plot accuracy
	pyplot.subplot(212)
	pyplot.title('Classification Accuracy')
	pyplot.plot(history.history['accuracy'], color='blue', label='train')
	pyplot.plot(history.history['val_accuracy'], color='orange', label='validation')
	# save plot to file
	filename = sys.argv[0].split('/')[-1]
	pyplot.savefig(filename + '_plot.png')
	# pyplot.close()

# %%
 # run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY,validationX, validationY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, validationX, testX = prep_pixels(trainX,validationX, testX)
	# define model
	model = define_model1()
 	# prepare iterator
	datagen = ImageDataGenerator()
	it_train = datagen.flow(trainX, trainY, batch_size=256)
	# fit model
	steps = int(trainX.shape[0] /256)
	history = model.fit(it_train, steps_per_epoch=steps, epochs=100, validation_data=(validationX, vlidationY), verbose=1)	# evaluate model
	_, acc = model.evaluate(validationX, validationY, verbose=1)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# Epoch 1/100
# 175/175 [==============================] - 5s 18ms/step - loss: 2.3975 - accuracy: 0.2311 - val_loss: 2.1868 - val_accuracy: 0.3076
# Epoch 2/100
# 175/175 [==============================] - 3s 16ms/step - loss: 2.1286 - accuracy: 0.3233 - val_loss: 2.0355 - val_accuracy: 0.3484
# Epoch 3/100
# 175/175 [==============================] - 3s 15ms/step - loss: 2.0034 - accuracy: 0.3625 - val_loss: 1.9478 - val_accuracy: 0.3803
# Epoch 4/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.9156 - accuracy: 0.3868 - val_loss: 1.8589 - val_accuracy: 0.3981
# Epoch 5/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.8363 - accuracy: 0.4080 - val_loss: 1.7954 - val_accuracy: 0.4139
# Epoch 6/100
# 175/175 [==============================] - 3s 15ms/step - loss: 1.7634 - accuracy: 0.4316 - val_loss: 1.7283 - val_accuracy: 0.4427
# Epoch 7/100
# 175/175 [==============================] - 3s 15ms/step - loss: 1.7024 - accuracy: 0.4493 - val_loss: 1.6757 - val_accuracy: 0.4508
# Epoch 8/100
# 175/175 [==============================] - 3s 15ms/step - loss: 1.6447 - accuracy: 0.4680 - val_loss: 1.6167 - val_accuracy: 0.4692
# Epoch 9/100
# 175/175 [==============================] - 3s 17ms/step - loss: 1.6004 - accuracy: 0.4816 - val_loss: 1.6012 - val_accuracy: 0.4741
# Epoch 10/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.5598 - accuracy: 0.4941 - val_loss: 1.5693 - val_accuracy: 0.4871
# Epoch 11/100
# 175/175 [==============================] - 4s 20ms/step - loss: 1.5207 - accuracy: 0.5084 - val_loss: 1.5252 - val_accuracy: 0.5007
# Epoch 12/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.4849 - accuracy: 0.5196 - val_loss: 1.5246 - val_accuracy: 0.4961
# Epoch 13/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.4597 - accuracy: 0.5282 - val_loss: 1.4900 - val_accuracy: 0.5087
# Epoch 14/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.4179 - accuracy: 0.5409 - val_loss: 1.4579 - val_accuracy: 0.5211
# Epoch 15/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.3928 - accuracy: 0.5521 - val_loss: 1.4285 - val_accuracy: 0.5361
# Epoch 16/100
# 175/175 [==============================] - 3s 15ms/step - loss: 1.3656 - accuracy: 0.5618 - val_loss: 1.4279 - val_accuracy: 0.5309
# Epoch 17/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.3403 - accuracy: 0.5681 - val_loss: 1.4171 - val_accuracy: 0.5319
# Epoch 18/100
# 175/175 [==============================] - 3s 17ms/step - loss: 1.3166 - accuracy: 0.5780 - val_loss: 1.3858 - val_accuracy: 0.5409
# Epoch 19/100
# 175/175 [==============================] - 3s 15ms/step - loss: 1.2924 - accuracy: 0.5839 - val_loss: 1.3680 - val_accuracy: 0.5424
# Epoch 20/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.2687 - accuracy: 0.5927 - val_loss: 1.3607 - val_accuracy: 0.5541
# Epoch 21/100
# 175/175 [==============================] - 4s 24ms/step - loss: 1.2443 - accuracy: 0.6012 - val_loss: 1.3415 - val_accuracy: 0.5621
# Epoch 22/100
# 175/175 [==============================] - 4s 25ms/step - loss: 1.2257 - accuracy: 0.6077 - val_loss: 1.3266 - val_accuracy: 0.5620
# Epoch 23/100
# 175/175 [==============================] - 4s 20ms/step - loss: 1.2068 - accuracy: 0.6123 - val_loss: 1.3279 - val_accuracy: 0.5649
# Epoch 24/100
# 175/175 [==============================] - 3s 17ms/step - loss: 1.1884 - accuracy: 0.6173 - val_loss: 1.3127 - val_accuracy: 0.5704
# Epoch 25/100
# 175/175 [==============================] - 3s 15ms/step - loss: 1.1615 - accuracy: 0.6285 - val_loss: 1.3447 - val_accuracy: 0.5565
# Epoch 26/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.1401 - accuracy: 0.6329 - val_loss: 1.2948 - val_accuracy: 0.5740
# Epoch 27/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.1251 - accuracy: 0.6374 - val_loss: 1.2822 - val_accuracy: 0.5833
# Epoch 28/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.1018 - accuracy: 0.6476 - val_loss: 1.2856 - val_accuracy: 0.5820
# Epoch 29/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.0873 - accuracy: 0.6502 - val_loss: 1.2962 - val_accuracy: 0.5771
# Epoch 30/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.0687 - accuracy: 0.6573 - val_loss: 1.3066 - val_accuracy: 0.5773
# Epoch 31/100
# 175/175 [==============================] - 3s 17ms/step - loss: 1.0511 - accuracy: 0.6616 - val_loss: 1.2911 - val_accuracy: 0.5801
# Epoch 32/100
# 175/175 [==============================] - 3s 17ms/step - loss: 1.0343 - accuracy: 0.6664 - val_loss: 1.2638 - val_accuracy: 0.5881
# Epoch 33/100
# 175/175 [==============================] - 3s 16ms/step - loss: 1.0197 - accuracy: 0.6731 - val_loss: 1.2678 - val_accuracy: 0.5908
# Epoch 34/100
# 175/175 [==============================] - 4s 21ms/step - loss: 0.9927 - accuracy: 0.6807 - val_loss: 1.2716 - val_accuracy: 0.5856
# Epoch 35/100
# 175/175 [==============================] - 3s 19ms/step - loss: 0.9795 - accuracy: 0.6838 - val_loss: 1.2675 - val_accuracy: 0.5911
# Epoch 36/100
# 175/175 [==============================] - 3s 15ms/step - loss: 0.9644 - accuracy: 0.6903 - val_loss: 1.2842 - val_accuracy: 0.5885
# Epoch 37/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.9435 - accuracy: 0.6962 - val_loss: 1.2802 - val_accuracy: 0.5899
# Epoch 38/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.9242 - accuracy: 0.7025 - val_loss: 1.2718 - val_accuracy: 0.5933
# Epoch 39/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.9162 - accuracy: 0.7062 - val_loss: 1.2857 - val_accuracy: 0.5908
# Epoch 40/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.8963 - accuracy: 0.7122 - val_loss: 1.2470 - val_accuracy: 0.6013
# Epoch 41/100
# 175/175 [==============================] - 3s 18ms/step - loss: 0.8787 - accuracy: 0.7175 - val_loss: 1.2841 - val_accuracy: 0.5843
# Epoch 42/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.8656 - accuracy: 0.7210 - val_loss: 1.2678 - val_accuracy: 0.5961
# Epoch 43/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.8428 - accuracy: 0.7305 - val_loss: 1.2987 - val_accuracy: 0.5836
# Epoch 44/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.8275 - accuracy: 0.7361 - val_loss: 1.2666 - val_accuracy: 0.5975
# Epoch 45/100
# 175/175 [==============================] - 3s 18ms/step - loss: 0.8118 - accuracy: 0.7402 - val_loss: 1.2615 - val_accuracy: 0.6015
# Epoch 46/100
# 175/175 [==============================] - 3s 19ms/step - loss: 0.7969 - accuracy: 0.7468 - val_loss: 1.2641 - val_accuracy: 0.5960
# Epoch 47/100
# 175/175 [==============================] - 3s 18ms/step - loss: 0.7782 - accuracy: 0.7519 - val_loss: 1.2600 - val_accuracy: 0.6061
# Epoch 48/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.7594 - accuracy: 0.7566 - val_loss: 1.2906 - val_accuracy: 0.5983
# Epoch 49/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.7449 - accuracy: 0.7649 - val_loss: 1.2919 - val_accuracy: 0.5983
# Epoch 50/100
# 175/175 [==============================] - 3s 15ms/step - loss: 0.7327 - accuracy: 0.7681 - val_loss: 1.2714 - val_accuracy: 0.6064
# Epoch 51/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.7080 - accuracy: 0.7764 - val_loss: 1.2858 - val_accuracy: 0.6036
# Epoch 52/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.6969 - accuracy: 0.7783 - val_loss: 1.3140 - val_accuracy: 0.5963
# Epoch 53/100
# 175/175 [==============================] - 3s 15ms/step - loss: 0.6798 - accuracy: 0.7853 - val_loss: 1.3202 - val_accuracy: 0.5967
# Epoch 54/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.6622 - accuracy: 0.7915 - val_loss: 1.3308 - val_accuracy: 0.6019
# Epoch 55/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.6525 - accuracy: 0.7951 - val_loss: 1.3108 - val_accuracy: 0.6060
# Epoch 56/100
# 175/175 [==============================] - 3s 15ms/step - loss: 0.6301 - accuracy: 0.8018 - val_loss: 1.3134 - val_accuracy: 0.6033
# Epoch 57/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.6140 - accuracy: 0.8067 - val_loss: 1.3239 - val_accuracy: 0.6045
# Epoch 58/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.6019 - accuracy: 0.8116 - val_loss: 1.3502 - val_accuracy: 0.6044
# Epoch 59/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.5881 - accuracy: 0.8174 - val_loss: 1.3483 - val_accuracy: 0.5995
# Epoch 60/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.5734 - accuracy: 0.8203 - val_loss: 1.3954 - val_accuracy: 0.5943
# Epoch 61/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.5542 - accuracy: 0.8285 - val_loss: 1.3944 - val_accuracy: 0.5945
# Epoch 62/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.5396 - accuracy: 0.8346 - val_loss: 1.3680 - val_accuracy: 0.6017
# Epoch 63/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.5219 - accuracy: 0.8406 - val_loss: 1.4102 - val_accuracy: 0.5977
# Epoch 64/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.5077 - accuracy: 0.8434 - val_loss: 1.4125 - val_accuracy: 0.5987
# Epoch 65/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.4884 - accuracy: 0.8527 - val_loss: 1.4345 - val_accuracy: 0.5952
# Epoch 66/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.4753 - accuracy: 0.8569 - val_loss: 1.4304 - val_accuracy: 0.5999
# Epoch 67/100
# 175/175 [==============================] - 3s 15ms/step - loss: 0.4613 - accuracy: 0.8620 - val_loss: 1.4334 - val_accuracy: 0.6015
# Epoch 68/100
# 175/175 [==============================] - 3s 15ms/step - loss: 0.4452 - accuracy: 0.8669 - val_loss: 1.4903 - val_accuracy: 0.5943
# Epoch 69/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.4353 - accuracy: 0.8709 - val_loss: 1.4856 - val_accuracy: 0.5928
# Epoch 70/100
# 175/175 [==============================] - 3s 18ms/step - loss: 0.4127 - accuracy: 0.8790 - val_loss: 1.4898 - val_accuracy: 0.5955
# Epoch 71/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.4001 - accuracy: 0.8828 - val_loss: 1.5080 - val_accuracy: 0.5949
# Epoch 72/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3846 - accuracy: 0.8884 - val_loss: 1.5368 - val_accuracy: 0.5907
# Epoch 73/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3744 - accuracy: 0.8931 - val_loss: 1.5490 - val_accuracy: 0.5932
# Epoch 74/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3612 - accuracy: 0.8967 - val_loss: 1.5759 - val_accuracy: 0.5951
# Epoch 75/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3544 - accuracy: 0.8974 - val_loss: 1.6085 - val_accuracy: 0.5869
# Epoch 76/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3326 - accuracy: 0.9079 - val_loss: 1.6365 - val_accuracy: 0.5833
# Epoch 77/100
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3199 - accuracy: 0.9100 - val_loss: 1.6359 - val_accuracy: 0.5916
# Epoch 78/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3103 - accuracy: 0.9146 - val_loss: 1.6797 - val_accuracy: 0.5900
# Epoch 79/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2943 - accuracy: 0.9193 - val_loss: 1.6652 - val_accuracy: 0.5885
# Epoch 80/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2726 - accuracy: 0.9291 - val_loss: 1.6635 - val_accuracy: 0.5924
# Epoch 81/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.2714 - accuracy: 0.9271 - val_loss: 1.6989 - val_accuracy: 0.5929
# Epoch 82/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.2566 - accuracy: 0.9330 - val_loss: 1.7062 - val_accuracy: 0.5947
# Epoch 83/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2445 - accuracy: 0.9383 - val_loss: 1.7470 - val_accuracy: 0.5932
# Epoch 84/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.2317 - accuracy: 0.9414 - val_loss: 1.7635 - val_accuracy: 0.5868
# Epoch 85/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.2251 - accuracy: 0.9437 - val_loss: 1.7856 - val_accuracy: 0.5885
# Epoch 86/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.2154 - accuracy: 0.9463 - val_loss: 1.8013 - val_accuracy: 0.5893
# Epoch 87/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.2069 - accuracy: 0.9491 - val_loss: 1.8507 - val_accuracy: 0.5872
# Epoch 88/100
# 175/175 [==============================] - 3s 15ms/step - loss: 0.1974 - accuracy: 0.9532 - val_loss: 1.8581 - val_accuracy: 0.5939
# Epoch 89/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.1853 - accuracy: 0.9579 - val_loss: 1.8745 - val_accuracy: 0.5868
# Epoch 90/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.1790 - accuracy: 0.9596 - val_loss: 1.8836 - val_accuracy: 0.5887
# Epoch 91/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.1620 - accuracy: 0.9660 - val_loss: 1.9427 - val_accuracy: 0.5889
# Epoch 92/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.1559 - accuracy: 0.9672 - val_loss: 1.9483 - val_accuracy: 0.5869
# Epoch 93/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.1399 - accuracy: 0.9745 - val_loss: 1.9852 - val_accuracy: 0.5903
# Epoch 94/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.1366 - accuracy: 0.9739 - val_loss: 1.9903 - val_accuracy: 0.5929
# Epoch 95/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.1277 - accuracy: 0.9772 - val_loss: 2.0100 - val_accuracy: 0.5887
# Epoch 96/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.1249 - accuracy: 0.9778 - val_loss: 2.0516 - val_accuracy: 0.5863
# Epoch 97/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.1161 - accuracy: 0.9800 - val_loss: 2.0771 - val_accuracy: 0.5847
# Epoch 98/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.1083 - accuracy: 0.9833 - val_loss: 2.1036 - val_accuracy: 0.5860
# Epoch 99/100
# 175/175 [==============================] - 3s 16ms/step - loss: 0.1037 - accuracy: 0.9839 - val_loss: 2.1130 - val_accuracy: 0.5860
# Epoch 100/100
# 175/175 [==============================] - 3s 17ms/step - loss: 0.0975 - accuracy: 0.9862 - val_loss: 2.1174 - val_accuracy: 0.5856
# 235/235 [==============================] - 1s 3ms/step - loss: 2.1174 - accuracy: 0.5856
# > 58.560

# %%
# VGG with 2 blocks
def define_model2():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(16, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# %%
 # run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY,validationX, validationY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, validationX, testX = prep_pixels(trainX,validationX, testX)
	# define model
	model = define_model2()
 	# prepare iterator
	datagen = ImageDataGenerator()
	it_train = datagen.flow(trainX, trainY, batch_size=256)
	# fit model
	steps = int(trainX.shape[0] /256)
	history = model.fit(it_train, steps_per_epoch=steps, epochs=100, validation_data=(validationX, vlidationY), verbose=1)	# evaluate model
	_, acc = model.evaluate(validationX, validationY, verbose=1)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# Epoch 1/100
# 175/175 [==============================] - 5s 25ms/step - loss: 2.4035 - accuracy: 0.2219 - val_loss: 2.1582 - val_accuracy: 0.3124
# Epoch 2/100
# 175/175 [==============================] - 4s 22ms/step - loss: 2.0724 - accuracy: 0.3345 - val_loss: 1.9572 - val_accuracy: 0.3680
# Epoch 3/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.8807 - accuracy: 0.3921 - val_loss: 1.7753 - val_accuracy: 0.4247
# Epoch 4/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.7625 - accuracy: 0.4282 - val_loss: 1.7259 - val_accuracy: 0.4327
# Epoch 5/100
# 175/175 [==============================] - 4s 22ms/step - loss: 1.6687 - accuracy: 0.4574 - val_loss: 1.6333 - val_accuracy: 0.4720
# Epoch 6/100
# 175/175 [==============================] - 4s 24ms/step - loss: 1.6101 - accuracy: 0.4778 - val_loss: 1.5743 - val_accuracy: 0.4907
# Epoch 7/100
# 175/175 [==============================] - 4s 25ms/step - loss: 1.5613 - accuracy: 0.4938 - val_loss: 1.5386 - val_accuracy: 0.4965
# Epoch 8/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.4998 - accuracy: 0.5138 - val_loss: 1.4951 - val_accuracy: 0.5161
# Epoch 9/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.4540 - accuracy: 0.5290 - val_loss: 1.4662 - val_accuracy: 0.5224
# Epoch 10/100
# 175/175 [==============================] - 4s 22ms/step - loss: 1.4160 - accuracy: 0.5414 - val_loss: 1.4181 - val_accuracy: 0.5369
# Epoch 11/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.3720 - accuracy: 0.5573 - val_loss: 1.3957 - val_accuracy: 0.5401
# Epoch 12/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.3362 - accuracy: 0.5658 - val_loss: 1.3738 - val_accuracy: 0.5591
# Epoch 13/100
# 175/175 [==============================] - 5s 26ms/step - loss: 1.2996 - accuracy: 0.5807 - val_loss: 1.3672 - val_accuracy: 0.5605
# Epoch 14/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.2696 - accuracy: 0.5900 - val_loss: 1.3400 - val_accuracy: 0.5652
# Epoch 15/100
# 175/175 [==============================] - 4s 22ms/step - loss: 1.2334 - accuracy: 0.6035 - val_loss: 1.3106 - val_accuracy: 0.5732
# Epoch 16/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.1989 - accuracy: 0.6129 - val_loss: 1.3165 - val_accuracy: 0.5739
# Epoch 17/100
# 175/175 [==============================] - 4s 22ms/step - loss: 1.1773 - accuracy: 0.6177 - val_loss: 1.2817 - val_accuracy: 0.5828
# Epoch 18/100
# 175/175 [==============================] - 4s 22ms/step - loss: 1.1455 - accuracy: 0.6305 - val_loss: 1.3348 - val_accuracy: 0.5701
# Epoch 19/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.1302 - accuracy: 0.6331 - val_loss: 1.2546 - val_accuracy: 0.5924
# Epoch 20/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.0991 - accuracy: 0.6448 - val_loss: 1.2518 - val_accuracy: 0.5923
# Epoch 21/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.0702 - accuracy: 0.6521 - val_loss: 1.2738 - val_accuracy: 0.5952
# Epoch 22/100
# 175/175 [==============================] - 4s 23ms/step - loss: 1.0528 - accuracy: 0.6597 - val_loss: 1.2816 - val_accuracy: 0.5881
# Epoch 23/100
# 175/175 [==============================] - 4s 22ms/step - loss: 1.0315 - accuracy: 0.6664 - val_loss: 1.2571 - val_accuracy: 0.5948
# Epoch 24/100
# 175/175 [==============================] - 4s 22ms/step - loss: 1.0079 - accuracy: 0.6748 - val_loss: 1.2304 - val_accuracy: 0.6067
# Epoch 25/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.9879 - accuracy: 0.6792 - val_loss: 1.2156 - val_accuracy: 0.6073
# Epoch 26/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.9651 - accuracy: 0.6884 - val_loss: 1.2179 - val_accuracy: 0.6119
# Epoch 27/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.9393 - accuracy: 0.6963 - val_loss: 1.2230 - val_accuracy: 0.6117
# Epoch 28/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.9189 - accuracy: 0.7024 - val_loss: 1.2130 - val_accuracy: 0.6117
# Epoch 29/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.9018 - accuracy: 0.7099 - val_loss: 1.2412 - val_accuracy: 0.6080
# Epoch 30/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.8812 - accuracy: 0.7132 - val_loss: 1.2126 - val_accuracy: 0.6177
# Epoch 31/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.8595 - accuracy: 0.7209 - val_loss: 1.2157 - val_accuracy: 0.6221
# Epoch 32/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.8384 - accuracy: 0.7287 - val_loss: 1.2417 - val_accuracy: 0.6099
# Epoch 33/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.8146 - accuracy: 0.7347 - val_loss: 1.2713 - val_accuracy: 0.6043
# Epoch 34/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.7990 - accuracy: 0.7398 - val_loss: 1.2402 - val_accuracy: 0.6175
# Epoch 35/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.7790 - accuracy: 0.7470 - val_loss: 1.2301 - val_accuracy: 0.6192
# Epoch 36/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.7551 - accuracy: 0.7558 - val_loss: 1.2376 - val_accuracy: 0.6201
# Epoch 37/100
# 175/175 [==============================] - 5s 26ms/step - loss: 0.7385 - accuracy: 0.7603 - val_loss: 1.2435 - val_accuracy: 0.6239
# Epoch 38/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.7225 - accuracy: 0.7644 - val_loss: 1.2532 - val_accuracy: 0.6188
# Epoch 39/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.6911 - accuracy: 0.7755 - val_loss: 1.3016 - val_accuracy: 0.6073
# Epoch 40/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.6711 - accuracy: 0.7843 - val_loss: 1.2785 - val_accuracy: 0.6153
# Epoch 41/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.6540 - accuracy: 0.7881 - val_loss: 1.3038 - val_accuracy: 0.6172
# Epoch 42/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.6335 - accuracy: 0.7938 - val_loss: 1.3162 - val_accuracy: 0.6212
# Epoch 43/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.6178 - accuracy: 0.7985 - val_loss: 1.3110 - val_accuracy: 0.6195
# Epoch 44/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.5955 - accuracy: 0.8086 - val_loss: 1.3156 - val_accuracy: 0.6244
# Epoch 45/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.5691 - accuracy: 0.8172 - val_loss: 1.3329 - val_accuracy: 0.6265
# Epoch 46/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.5493 - accuracy: 0.8227 - val_loss: 1.3537 - val_accuracy: 0.6152
# Epoch 47/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.5411 - accuracy: 0.8248 - val_loss: 1.3777 - val_accuracy: 0.6128
# Epoch 48/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.5106 - accuracy: 0.8374 - val_loss: 1.3864 - val_accuracy: 0.6195
# Epoch 49/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.4870 - accuracy: 0.8441 - val_loss: 1.4508 - val_accuracy: 0.6157
# Epoch 50/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.4874 - accuracy: 0.8405 - val_loss: 1.4447 - val_accuracy: 0.6128
# Epoch 51/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.4514 - accuracy: 0.8544 - val_loss: 1.4637 - val_accuracy: 0.6109
# Epoch 52/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.4277 - accuracy: 0.8641 - val_loss: 1.5119 - val_accuracy: 0.6053
# Epoch 53/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.4179 - accuracy: 0.8658 - val_loss: 1.5305 - val_accuracy: 0.6043
# Epoch 54/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.3907 - accuracy: 0.8779 - val_loss: 1.5826 - val_accuracy: 0.6039
# Epoch 55/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3723 - accuracy: 0.8823 - val_loss: 1.5884 - val_accuracy: 0.6079
# Epoch 56/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3512 - accuracy: 0.8900 - val_loss: 1.6387 - val_accuracy: 0.6044
# Epoch 57/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.3528 - accuracy: 0.8860 - val_loss: 1.6295 - val_accuracy: 0.6112
# Epoch 58/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.3197 - accuracy: 0.9021 - val_loss: 1.7065 - val_accuracy: 0.5997
# Epoch 59/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.3019 - accuracy: 0.9077 - val_loss: 1.7393 - val_accuracy: 0.5975
# Epoch 60/100
# 175/175 [==============================] - 5s 26ms/step - loss: 0.2809 - accuracy: 0.9151 - val_loss: 1.7795 - val_accuracy: 0.6021
# Epoch 61/100
# 175/175 [==============================] - 4s 24ms/step - loss: 0.2686 - accuracy: 0.9173 - val_loss: 1.8277 - val_accuracy: 0.6001
# Epoch 62/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.2497 - accuracy: 0.9245 - val_loss: 1.8987 - val_accuracy: 0.6016
# Epoch 63/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.2277 - accuracy: 0.9328 - val_loss: 1.8773 - val_accuracy: 0.6043
# Epoch 64/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.2201 - accuracy: 0.9338 - val_loss: 1.9431 - val_accuracy: 0.6003
# Epoch 65/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.2041 - accuracy: 0.9402 - val_loss: 1.9874 - val_accuracy: 0.5980
# Epoch 66/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.1875 - accuracy: 0.9454 - val_loss: 2.0355 - val_accuracy: 0.5984
# Epoch 67/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.1682 - accuracy: 0.9535 - val_loss: 2.1089 - val_accuracy: 0.5984
# Epoch 68/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.1551 - accuracy: 0.9569 - val_loss: 2.1371 - val_accuracy: 0.5977
# Epoch 69/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.1361 - accuracy: 0.9648 - val_loss: 2.2813 - val_accuracy: 0.5909
# Epoch 70/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.1363 - accuracy: 0.9630 - val_loss: 2.2581 - val_accuracy: 0.5976
# Epoch 71/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.1137 - accuracy: 0.9732 - val_loss: 2.3014 - val_accuracy: 0.5988
# Epoch 72/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0999 - accuracy: 0.9777 - val_loss: 2.3701 - val_accuracy: 0.6009
# Epoch 73/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.0982 - accuracy: 0.9768 - val_loss: 2.4250 - val_accuracy: 0.5923
# Epoch 74/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0879 - accuracy: 0.9798 - val_loss: 2.5476 - val_accuracy: 0.5872
# Epoch 75/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0739 - accuracy: 0.9852 - val_loss: 2.5307 - val_accuracy: 0.5963
# Epoch 76/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0690 - accuracy: 0.9865 - val_loss: 2.6318 - val_accuracy: 0.5941
# Epoch 77/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0819 - accuracy: 0.9796 - val_loss: 2.6317 - val_accuracy: 0.5933
# Epoch 78/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.0538 - accuracy: 0.9913 - val_loss: 2.6856 - val_accuracy: 0.5976
# Epoch 79/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0429 - accuracy: 0.9941 - val_loss: 2.7611 - val_accuracy: 0.5953
# Epoch 80/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.0375 - accuracy: 0.9956 - val_loss: 2.7979 - val_accuracy: 0.6004
# Epoch 81/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0321 - accuracy: 0.9969 - val_loss: 2.8562 - val_accuracy: 0.5996
# Epoch 82/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0270 - accuracy: 0.9978 - val_loss: 2.8970 - val_accuracy: 0.5953
# Epoch 83/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0222 - accuracy: 0.9987 - val_loss: 2.9390 - val_accuracy: 0.5952
# Epoch 84/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0198 - accuracy: 0.9991 - val_loss: 3.0093 - val_accuracy: 0.5945
# Epoch 85/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0181 - accuracy: 0.9993 - val_loss: 3.0144 - val_accuracy: 0.5963
# Epoch 86/100
# 175/175 [==============================] - 4s 24ms/step - loss: 0.0154 - accuracy: 0.9994 - val_loss: 3.0784 - val_accuracy: 0.5963
# Epoch 87/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0137 - accuracy: 0.9996 - val_loss: 3.1247 - val_accuracy: 0.5976
# Epoch 88/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0125 - accuracy: 0.9997 - val_loss: 3.1447 - val_accuracy: 0.5955
# Epoch 89/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0112 - accuracy: 0.9998 - val_loss: 3.1924 - val_accuracy: 0.5973
# Epoch 90/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0099 - accuracy: 0.9999 - val_loss: 3.2259 - val_accuracy: 0.5968
# Epoch 91/100
# 175/175 [==============================] - 4s 22ms/step - loss: 0.0092 - accuracy: 0.9999 - val_loss: 3.2643 - val_accuracy: 0.5953
# Epoch 92/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0085 - accuracy: 0.9999 - val_loss: 3.2941 - val_accuracy: 0.5981
# Epoch 93/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0080 - accuracy: 0.9999 - val_loss: 3.3209 - val_accuracy: 0.5956
# Epoch 94/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0076 - accuracy: 0.9999 - val_loss: 3.3440 - val_accuracy: 0.5955
# Epoch 95/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0071 - accuracy: 0.9999 - val_loss: 3.3725 - val_accuracy: 0.5961
# Epoch 96/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0067 - accuracy: 0.9999 - val_loss: 3.4016 - val_accuracy: 0.5963
# Epoch 97/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0063 - accuracy: 0.9999 - val_loss: 3.4279 - val_accuracy: 0.5935
# Epoch 98/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 3.4643 - val_accuracy: 0.5951
# Epoch 99/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 3.4800 - val_accuracy: 0.5929
# Epoch 100/100
# 175/175 [==============================] - 4s 23ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 3.5040 - val_accuracy: 0.5985
# 235/235 [==============================] - 1s 4ms/step - loss: 3.5040 - accuracy: 0.5985
# > 59.853

# %%
# VGG with 3 blocks

# define cnn model
def define_model3():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(16, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# %%
 # run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY,validationX, validationY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, validationX, testX = prep_pixels(trainX,validationX, testX)
	# define model
	model = define_model3()
 	# prepare iterator
	datagen = ImageDataGenerator()
	it_train = datagen.flow(trainX, trainY, batch_size=256)
	# fit model
	steps = int(trainX.shape[0] /256)
	history = model.fit(it_train, steps_per_epoch=steps, epochs=100, validation_data=(validationX, vlidationY), verbose=1)	# evaluate model
	_, acc = model.evaluate(validationX, validationY, verbose=1)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# Epoch 1/100
# 175/175 [==============================] - 7s 33ms/step - loss: 2.4292 - accuracy: 0.2069 - val_loss: 2.1816 - val_accuracy: 0.2980
# Epoch 2/100
# 175/175 [==============================] - 5s 27ms/step - loss: 2.0819 - accuracy: 0.3253 - val_loss: 2.0358 - val_accuracy: 0.3411
# Epoch 3/100
# 175/175 [==============================] - 5s 26ms/step - loss: 1.9053 - accuracy: 0.3792 - val_loss: 1.8762 - val_accuracy: 0.3856
# Epoch 4/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.8097 - accuracy: 0.4080 - val_loss: 1.7379 - val_accuracy: 0.4219
# Epoch 5/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.7212 - accuracy: 0.4395 - val_loss: 1.6695 - val_accuracy: 0.4451
# Epoch 6/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.6497 - accuracy: 0.4595 - val_loss: 1.6016 - val_accuracy: 0.4735
# Epoch 7/100
# 175/175 [==============================] - 5s 29ms/step - loss: 1.5922 - accuracy: 0.4815 - val_loss: 1.5732 - val_accuracy: 0.4864
# Epoch 8/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.5383 - accuracy: 0.4987 - val_loss: 1.5514 - val_accuracy: 0.4909
# Epoch 9/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.4852 - accuracy: 0.5153 - val_loss: 1.4885 - val_accuracy: 0.5161
# Epoch 10/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.4384 - accuracy: 0.5320 - val_loss: 1.4361 - val_accuracy: 0.5316
# Epoch 11/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.3980 - accuracy: 0.5458 - val_loss: 1.4306 - val_accuracy: 0.5273
# Epoch 12/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.3498 - accuracy: 0.5593 - val_loss: 1.4005 - val_accuracy: 0.5395
# Epoch 13/100
# 175/175 [==============================] - 5s 26ms/step - loss: 1.3184 - accuracy: 0.5690 - val_loss: 1.3733 - val_accuracy: 0.5483
# Epoch 14/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.2758 - accuracy: 0.5835 - val_loss: 1.3844 - val_accuracy: 0.5521
# Epoch 15/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.2372 - accuracy: 0.5989 - val_loss: 1.3426 - val_accuracy: 0.5688
# Epoch 16/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.2121 - accuracy: 0.6055 - val_loss: 1.3061 - val_accuracy: 0.5753
# Epoch 17/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.1754 - accuracy: 0.6163 - val_loss: 1.2795 - val_accuracy: 0.5839
# Epoch 18/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.1422 - accuracy: 0.6278 - val_loss: 1.2958 - val_accuracy: 0.5761
# Epoch 19/100
# 175/175 [==============================] - 5s 26ms/step - loss: 1.1141 - accuracy: 0.6391 - val_loss: 1.2317 - val_accuracy: 0.5935
# Epoch 20/100
# 175/175 [==============================] - 5s 29ms/step - loss: 1.0790 - accuracy: 0.6486 - val_loss: 1.2523 - val_accuracy: 0.5915
# Epoch 21/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0639 - accuracy: 0.6539 - val_loss: 1.2631 - val_accuracy: 0.5912
# Epoch 22/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.0224 - accuracy: 0.6694 - val_loss: 1.2206 - val_accuracy: 0.6071
# Epoch 23/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.0071 - accuracy: 0.6725 - val_loss: 1.2100 - val_accuracy: 0.6037
# Epoch 24/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.9722 - accuracy: 0.6839 - val_loss: 1.2122 - val_accuracy: 0.6080
# Epoch 25/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.9510 - accuracy: 0.6900 - val_loss: 1.2446 - val_accuracy: 0.5976
# Epoch 26/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.9323 - accuracy: 0.6946 - val_loss: 1.2507 - val_accuracy: 0.6041
# Epoch 27/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.9016 - accuracy: 0.7041 - val_loss: 1.2167 - val_accuracy: 0.6092
# Epoch 28/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.8717 - accuracy: 0.7150 - val_loss: 1.2345 - val_accuracy: 0.6104
# Epoch 29/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.8465 - accuracy: 0.7242 - val_loss: 1.2393 - val_accuracy: 0.6025
# Epoch 30/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.8221 - accuracy: 0.7313 - val_loss: 1.2108 - val_accuracy: 0.6213
# Epoch 31/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.8027 - accuracy: 0.7384 - val_loss: 1.2277 - val_accuracy: 0.6073
# Epoch 32/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.7878 - accuracy: 0.7433 - val_loss: 1.2244 - val_accuracy: 0.6205
# Epoch 33/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.7566 - accuracy: 0.7512 - val_loss: 1.2275 - val_accuracy: 0.6233
# Epoch 34/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.7237 - accuracy: 0.7623 - val_loss: 1.2380 - val_accuracy: 0.6208
# Epoch 35/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.7129 - accuracy: 0.7655 - val_loss: 1.3189 - val_accuracy: 0.6020
# Epoch 36/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.6834 - accuracy: 0.7772 - val_loss: 1.2825 - val_accuracy: 0.6117
# Epoch 37/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.6631 - accuracy: 0.7836 - val_loss: 1.2826 - val_accuracy: 0.6155
# Epoch 38/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.6429 - accuracy: 0.7895 - val_loss: 1.2832 - val_accuracy: 0.6148
# Epoch 39/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.6124 - accuracy: 0.7986 - val_loss: 1.2949 - val_accuracy: 0.6241
# Epoch 40/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.5845 - accuracy: 0.8076 - val_loss: 1.2981 - val_accuracy: 0.6241
# Epoch 41/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.5518 - accuracy: 0.8182 - val_loss: 1.3025 - val_accuracy: 0.6300
# Epoch 42/100
# 175/175 [==============================] - 5s 30ms/step - loss: 0.5396 - accuracy: 0.8223 - val_loss: 1.3198 - val_accuracy: 0.6259
# Epoch 43/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.5040 - accuracy: 0.8341 - val_loss: 1.4144 - val_accuracy: 0.6244
# Epoch 44/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.4921 - accuracy: 0.8369 - val_loss: 1.4344 - val_accuracy: 0.6191
# Epoch 45/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.4681 - accuracy: 0.8466 - val_loss: 1.4110 - val_accuracy: 0.6239
# Epoch 46/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.4436 - accuracy: 0.8547 - val_loss: 1.4361 - val_accuracy: 0.6235
# Epoch 47/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.4082 - accuracy: 0.8668 - val_loss: 1.4921 - val_accuracy: 0.6228
# Epoch 48/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.4046 - accuracy: 0.8653 - val_loss: 1.5560 - val_accuracy: 0.6211
# Epoch 49/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.3701 - accuracy: 0.8798 - val_loss: 1.5419 - val_accuracy: 0.6172
# Epoch 50/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.3658 - accuracy: 0.8790 - val_loss: 1.6014 - val_accuracy: 0.6073
# Epoch 51/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.3350 - accuracy: 0.8902 - val_loss: 1.6679 - val_accuracy: 0.6045
# Epoch 52/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.3122 - accuracy: 0.8993 - val_loss: 1.6312 - val_accuracy: 0.6152
# Epoch 53/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.3005 - accuracy: 0.9007 - val_loss: 1.6309 - val_accuracy: 0.6204
# Epoch 54/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.2668 - accuracy: 0.9139 - val_loss: 1.7051 - val_accuracy: 0.6172
# Epoch 55/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.2398 - accuracy: 0.9234 - val_loss: 1.7807 - val_accuracy: 0.6092
# Epoch 56/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.2448 - accuracy: 0.9190 - val_loss: 1.8269 - val_accuracy: 0.6171
# Epoch 57/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.2199 - accuracy: 0.9286 - val_loss: 1.9120 - val_accuracy: 0.6192
# Epoch 58/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.1860 - accuracy: 0.9424 - val_loss: 1.8974 - val_accuracy: 0.6201
# Epoch 59/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.1779 - accuracy: 0.9446 - val_loss: 1.9928 - val_accuracy: 0.6212
# Epoch 60/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.1563 - accuracy: 0.9517 - val_loss: 2.0504 - val_accuracy: 0.6121
# Epoch 61/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.1414 - accuracy: 0.9583 - val_loss: 2.1143 - val_accuracy: 0.6116
# Epoch 62/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.1739 - accuracy: 0.9425 - val_loss: 2.1691 - val_accuracy: 0.6057
# Epoch 63/100
# 175/175 [==============================] - 6s 34ms/step - loss: 0.1236 - accuracy: 0.9631 - val_loss: 2.1770 - val_accuracy: 0.6144
# Epoch 64/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.1041 - accuracy: 0.9704 - val_loss: 2.2135 - val_accuracy: 0.6144
# Epoch 65/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0859 - accuracy: 0.9776 - val_loss: 2.3647 - val_accuracy: 0.6143
# Epoch 66/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.1005 - accuracy: 0.9705 - val_loss: 2.3844 - val_accuracy: 0.6096
# Epoch 67/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0854 - accuracy: 0.9762 - val_loss: 2.4401 - val_accuracy: 0.6143
# Epoch 68/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0809 - accuracy: 0.9777 - val_loss: 2.4985 - val_accuracy: 0.6119
# Epoch 69/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0700 - accuracy: 0.9808 - val_loss: 2.5574 - val_accuracy: 0.6103
# Epoch 70/100
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0661 - accuracy: 0.9821 - val_loss: 2.5785 - val_accuracy: 0.6124
# Epoch 71/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0409 - accuracy: 0.9920 - val_loss: 2.7007 - val_accuracy: 0.6057
# Epoch 72/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0296 - accuracy: 0.9957 - val_loss: 2.6992 - val_accuracy: 0.6116
# Epoch 73/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0201 - accuracy: 0.9981 - val_loss: 2.7904 - val_accuracy: 0.6183
# Epoch 74/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0132 - accuracy: 0.9993 - val_loss: 2.8207 - val_accuracy: 0.6155
# Epoch 75/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0108 - accuracy: 0.9996 - val_loss: 2.8779 - val_accuracy: 0.6177
# Epoch 76/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0084 - accuracy: 0.9998 - val_loss: 2.9283 - val_accuracy: 0.6185
# Epoch 77/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0072 - accuracy: 0.9999 - val_loss: 2.9780 - val_accuracy: 0.6207
# Epoch 78/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0062 - accuracy: 0.9999 - val_loss: 3.0171 - val_accuracy: 0.6172
# Epoch 79/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 3.0706 - val_accuracy: 0.6188
# Epoch 80/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 3.0976 - val_accuracy: 0.6208
# Epoch 81/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.1165 - val_accuracy: 0.6197
# Epoch 82/100
# 175/175 [==============================] - 6s 32ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 3.1463 - val_accuracy: 0.6185
# Epoch 83/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 3.1852 - val_accuracy: 0.6189
# Epoch 84/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.2152 - val_accuracy: 0.6203
# Epoch 85/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 3.2341 - val_accuracy: 0.6200
# Epoch 86/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.2610 - val_accuracy: 0.6188
# Epoch 87/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 3.2812 - val_accuracy: 0.6205
# Epoch 88/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.3036 - val_accuracy: 0.6204
# Epoch 89/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 3.3324 - val_accuracy: 0.6211
# Epoch 90/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.3484 - val_accuracy: 0.6199
# Epoch 91/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.3704 - val_accuracy: 0.6203
# Epoch 92/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.3873 - val_accuracy: 0.6196
# Epoch 93/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.4051 - val_accuracy: 0.6212
# Epoch 94/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.4230 - val_accuracy: 0.6188
# Epoch 95/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.4360 - val_accuracy: 0.6205
# Epoch 96/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.4594 - val_accuracy: 0.6200
# Epoch 97/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.4756 - val_accuracy: 0.6193
# Epoch 98/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.4945 - val_accuracy: 0.6195
# Epoch 99/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.5114 - val_accuracy: 0.6205
# Epoch 100/100
# 175/175 [==============================] - 5s 30ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.5201 - val_accuracy: 0.6193
# 235/235 [==============================] - 1s 6ms/step - loss: 3.5201 - accuracy: 0.6193
# > 61.933

# %%
# overfitting. try dropout

# %%
# define cnn model
def define_model_with_drop_out():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dropout(0.2))
	model.add(Dense(16, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# %%
 # run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY,validationX, validationY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, validationX, testX = prep_pixels(trainX,validationX, testX)
	# define model
	model = define_model_with_drop_out()
 	# prepare iterator
	datagen = ImageDataGenerator()
	it_train = datagen.flow(trainX, trainY, batch_size=256)
	# fit model
	steps = int(trainX.shape[0] /256)
	history = model.fit(it_train, steps_per_epoch=steps, epochs=100, validation_data=(validationX, vlidationY), verbose=1)	# evaluate model
	_, acc = model.evaluate(validationX, validationY, verbose=1)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# Epoch 1/100
# 175/175 [==============================] - 6s 29ms/step - loss: 2.7593 - accuracy: 0.0892 - val_loss: 2.6658 - val_accuracy: 0.1452
# Epoch 2/100
# 175/175 [==============================] - 5s 27ms/step - loss: 2.6327 - accuracy: 0.1223 - val_loss: 2.5257 - val_accuracy: 0.1912
# Epoch 3/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.4819 - accuracy: 0.1740 - val_loss: 2.3885 - val_accuracy: 0.2209
# Epoch 4/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.3835 - accuracy: 0.2053 - val_loss: 2.3114 - val_accuracy: 0.2569
# Epoch 5/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.2809 - accuracy: 0.2444 - val_loss: 2.1456 - val_accuracy: 0.3135
# Epoch 6/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.1831 - accuracy: 0.2768 - val_loss: 2.0758 - val_accuracy: 0.3243
# Epoch 7/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.1134 - accuracy: 0.2980 - val_loss: 1.9710 - val_accuracy: 0.3625
# Epoch 8/100
# 175/175 [==============================] - 6s 31ms/step - loss: 2.0543 - accuracy: 0.3176 - val_loss: 1.9126 - val_accuracy: 0.3704
# Epoch 9/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.0093 - accuracy: 0.3305 - val_loss: 1.8809 - val_accuracy: 0.3908
# Epoch 10/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.9641 - accuracy: 0.3446 - val_loss: 1.8604 - val_accuracy: 0.3853
# Epoch 11/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.9349 - accuracy: 0.3539 - val_loss: 1.8047 - val_accuracy: 0.4079
# Epoch 12/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.8930 - accuracy: 0.3700 - val_loss: 1.7757 - val_accuracy: 0.4139
# Epoch 13/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.8628 - accuracy: 0.3778 - val_loss: 1.7272 - val_accuracy: 0.4269
# Epoch 14/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.8350 - accuracy: 0.3886 - val_loss: 1.6913 - val_accuracy: 0.4384
# Epoch 15/100
# 175/175 [==============================] - 5s 30ms/step - loss: 1.8023 - accuracy: 0.3983 - val_loss: 1.6766 - val_accuracy: 0.4515
# Epoch 16/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.7768 - accuracy: 0.4092 - val_loss: 1.6454 - val_accuracy: 0.4645
# Epoch 17/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.7460 - accuracy: 0.4187 - val_loss: 1.6073 - val_accuracy: 0.4640
# Epoch 18/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.7299 - accuracy: 0.4256 - val_loss: 1.6090 - val_accuracy: 0.4596
# Epoch 19/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.7059 - accuracy: 0.4328 - val_loss: 1.5720 - val_accuracy: 0.4831
# Epoch 20/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.6858 - accuracy: 0.4405 - val_loss: 1.5397 - val_accuracy: 0.4920
# Epoch 21/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.6585 - accuracy: 0.4483 - val_loss: 1.5368 - val_accuracy: 0.4904
# Epoch 22/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.6407 - accuracy: 0.4549 - val_loss: 1.5084 - val_accuracy: 0.5011
# Epoch 23/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.6207 - accuracy: 0.4638 - val_loss: 1.4937 - val_accuracy: 0.5093
# Epoch 24/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.6156 - accuracy: 0.4652 - val_loss: 1.4721 - val_accuracy: 0.5131
# Epoch 25/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.5811 - accuracy: 0.4755 - val_loss: 1.4528 - val_accuracy: 0.5189
# Epoch 26/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.5654 - accuracy: 0.4807 - val_loss: 1.4359 - val_accuracy: 0.5199
# Epoch 27/100
# 175/175 [==============================] - 5s 30ms/step - loss: 1.5464 - accuracy: 0.4866 - val_loss: 1.4160 - val_accuracy: 0.5292
# Epoch 28/100
# 175/175 [==============================] - 6s 32ms/step - loss: 1.5281 - accuracy: 0.4934 - val_loss: 1.4102 - val_accuracy: 0.5344
# Epoch 29/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.5148 - accuracy: 0.4971 - val_loss: 1.3926 - val_accuracy: 0.5356
# Epoch 30/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.5022 - accuracy: 0.5033 - val_loss: 1.3816 - val_accuracy: 0.5432
# Epoch 31/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.4810 - accuracy: 0.5086 - val_loss: 1.3461 - val_accuracy: 0.5539
# Epoch 32/100
# 175/175 [==============================] - 5s 30ms/step - loss: 1.4702 - accuracy: 0.5153 - val_loss: 1.3498 - val_accuracy: 0.5517
# Epoch 33/100
# 175/175 [==============================] - 6s 32ms/step - loss: 1.4493 - accuracy: 0.5198 - val_loss: 1.3271 - val_accuracy: 0.5565
# Epoch 34/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.4384 - accuracy: 0.5247 - val_loss: 1.3084 - val_accuracy: 0.5649
# Epoch 35/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.4197 - accuracy: 0.5304 - val_loss: 1.3065 - val_accuracy: 0.5663
# Epoch 36/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.4082 - accuracy: 0.5376 - val_loss: 1.2877 - val_accuracy: 0.5704
# Epoch 37/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.3892 - accuracy: 0.5420 - val_loss: 1.2792 - val_accuracy: 0.5759
# Epoch 38/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.3821 - accuracy: 0.5443 - val_loss: 1.2684 - val_accuracy: 0.5820
# Epoch 39/100
# 175/175 [==============================] - 6s 31ms/step - loss: 1.3578 - accuracy: 0.5518 - val_loss: 1.2546 - val_accuracy: 0.5855
# Epoch 40/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.3494 - accuracy: 0.5544 - val_loss: 1.2367 - val_accuracy: 0.5871
# Epoch 41/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.3378 - accuracy: 0.5554 - val_loss: 1.2466 - val_accuracy: 0.5839
# Epoch 42/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.3193 - accuracy: 0.5637 - val_loss: 1.1989 - val_accuracy: 0.6027
# Epoch 43/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.3167 - accuracy: 0.5643 - val_loss: 1.1899 - val_accuracy: 0.6037
# Epoch 44/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2979 - accuracy: 0.5717 - val_loss: 1.1861 - val_accuracy: 0.6057
# Epoch 45/100
# 175/175 [==============================] - 6s 34ms/step - loss: 1.2865 - accuracy: 0.5771 - val_loss: 1.1685 - val_accuracy: 0.6121
# Epoch 46/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2780 - accuracy: 0.5767 - val_loss: 1.1633 - val_accuracy: 0.6139
# Epoch 47/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2648 - accuracy: 0.5794 - val_loss: 1.1801 - val_accuracy: 0.6064
# Epoch 48/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2623 - accuracy: 0.5846 - val_loss: 1.1532 - val_accuracy: 0.6157
# Epoch 49/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2459 - accuracy: 0.5885 - val_loss: 1.1515 - val_accuracy: 0.6151
# Epoch 50/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2382 - accuracy: 0.5892 - val_loss: 1.1154 - val_accuracy: 0.6345
# Epoch 51/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2275 - accuracy: 0.5922 - val_loss: 1.1231 - val_accuracy: 0.6303
# Epoch 52/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2151 - accuracy: 0.5984 - val_loss: 1.1241 - val_accuracy: 0.6245
# Epoch 53/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2074 - accuracy: 0.6036 - val_loss: 1.1024 - val_accuracy: 0.6397
# Epoch 54/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2004 - accuracy: 0.6032 - val_loss: 1.1049 - val_accuracy: 0.6321
# Epoch 55/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1904 - accuracy: 0.6082 - val_loss: 1.0858 - val_accuracy: 0.6380
# Epoch 56/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1747 - accuracy: 0.6117 - val_loss: 1.1042 - val_accuracy: 0.6337
# Epoch 57/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1717 - accuracy: 0.6127 - val_loss: 1.0752 - val_accuracy: 0.6424
# Epoch 58/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1593 - accuracy: 0.6178 - val_loss: 1.0870 - val_accuracy: 0.6415
# Epoch 59/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1490 - accuracy: 0.6180 - val_loss: 1.0517 - val_accuracy: 0.6511
# Epoch 60/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1498 - accuracy: 0.6178 - val_loss: 1.0880 - val_accuracy: 0.6416
# Epoch 61/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1398 - accuracy: 0.6247 - val_loss: 1.0446 - val_accuracy: 0.6527
# Epoch 62/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1291 - accuracy: 0.6248 - val_loss: 1.0259 - val_accuracy: 0.6613
# Epoch 63/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.1193 - accuracy: 0.6285 - val_loss: 1.0246 - val_accuracy: 0.6595
# Epoch 64/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1085 - accuracy: 0.6340 - val_loss: 1.0282 - val_accuracy: 0.6603
# Epoch 65/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.1013 - accuracy: 0.6366 - val_loss: 1.0385 - val_accuracy: 0.6572
# Epoch 66/100
# 175/175 [==============================] - 7s 39ms/step - loss: 1.0930 - accuracy: 0.6385 - val_loss: 0.9986 - val_accuracy: 0.6680
# Epoch 67/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0930 - accuracy: 0.6383 - val_loss: 1.0089 - val_accuracy: 0.6676
# Epoch 68/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.0777 - accuracy: 0.6437 - val_loss: 0.9952 - val_accuracy: 0.6688
# Epoch 69/100
# 175/175 [==============================] - 5s 29ms/step - loss: 1.0776 - accuracy: 0.6424 - val_loss: 0.9915 - val_accuracy: 0.6743
# Epoch 70/100
# 175/175 [==============================] - 6s 35ms/step - loss: 1.0725 - accuracy: 0.6468 - val_loss: 0.9904 - val_accuracy: 0.6751
# Epoch 71/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0649 - accuracy: 0.6457 - val_loss: 0.9891 - val_accuracy: 0.6732
# Epoch 72/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0557 - accuracy: 0.6506 - val_loss: 0.9733 - val_accuracy: 0.6828
# Epoch 73/100
# 175/175 [==============================] - 6s 32ms/step - loss: 1.0432 - accuracy: 0.6551 - val_loss: 0.9962 - val_accuracy: 0.6691
# Epoch 74/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0385 - accuracy: 0.6552 - val_loss: 0.9689 - val_accuracy: 0.6801
# Epoch 75/100
# 175/175 [==============================] - 5s 29ms/step - loss: 1.0405 - accuracy: 0.6564 - val_loss: 0.9585 - val_accuracy: 0.6839
# Epoch 76/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0244 - accuracy: 0.6627 - val_loss: 0.9684 - val_accuracy: 0.6777
# Epoch 77/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0211 - accuracy: 0.6638 - val_loss: 0.9450 - val_accuracy: 0.6875
# Epoch 78/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0136 - accuracy: 0.6647 - val_loss: 0.9356 - val_accuracy: 0.6909
# Epoch 79/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0045 - accuracy: 0.6676 - val_loss: 0.9423 - val_accuracy: 0.6868
# Epoch 80/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9996 - accuracy: 0.6692 - val_loss: 0.9458 - val_accuracy: 0.6884
# Epoch 81/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9982 - accuracy: 0.6702 - val_loss: 0.9239 - val_accuracy: 0.6948
# Epoch 82/100
# 175/175 [==============================] - 6s 35ms/step - loss: 0.9889 - accuracy: 0.6708 - val_loss: 0.9347 - val_accuracy: 0.6884
# Epoch 83/100
# 175/175 [==============================] - 5s 30ms/step - loss: 0.9863 - accuracy: 0.6715 - val_loss: 0.9400 - val_accuracy: 0.6915
# Epoch 84/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9758 - accuracy: 0.6772 - val_loss: 0.9276 - val_accuracy: 0.6928
# Epoch 85/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9729 - accuracy: 0.6779 - val_loss: 0.9241 - val_accuracy: 0.6905
# Epoch 86/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9674 - accuracy: 0.6774 - val_loss: 0.9249 - val_accuracy: 0.6932
# Epoch 87/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9651 - accuracy: 0.6797 - val_loss: 0.9142 - val_accuracy: 0.6956
# Epoch 88/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9515 - accuracy: 0.6839 - val_loss: 0.9143 - val_accuracy: 0.6971
# Epoch 89/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9576 - accuracy: 0.6860 - val_loss: 0.9129 - val_accuracy: 0.6965
# Epoch 90/100
# 175/175 [==============================] - 5s 29ms/step - loss: 0.9415 - accuracy: 0.6863 - val_loss: 0.9086 - val_accuracy: 0.6989
# Epoch 91/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9343 - accuracy: 0.6893 - val_loss: 0.8931 - val_accuracy: 0.7019
# Epoch 92/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9377 - accuracy: 0.6889 - val_loss: 0.8958 - val_accuracy: 0.6987
# Epoch 93/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9295 - accuracy: 0.6909 - val_loss: 0.8883 - val_accuracy: 0.7071
# Epoch 94/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9262 - accuracy: 0.6947 - val_loss: 0.8773 - val_accuracy: 0.7063
# Epoch 95/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9134 - accuracy: 0.6969 - val_loss: 0.8989 - val_accuracy: 0.7035
# Epoch 96/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9170 - accuracy: 0.6975 - val_loss: 0.8788 - val_accuracy: 0.7085
# Epoch 97/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9106 - accuracy: 0.6980 - val_loss: 0.8757 - val_accuracy: 0.7107
# Epoch 98/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9002 - accuracy: 0.7006 - val_loss: 0.8698 - val_accuracy: 0.7132
# Epoch 99/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.8984 - accuracy: 0.7035 - val_loss: 0.8715 - val_accuracy: 0.7113
# Epoch 100/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.8976 - accuracy: 0.7014 - val_loss: 0.8605 - val_accuracy: 0.7147
# 235/235 [==============================] - 1s 3ms/step - loss: 0.8605 - accuracy: 0.7147
# > 71.467

# %%
# much better!!!

# %%
from keras.regularizers import l2

# define cnn model
def define_model_weight_decay():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(0.001), input_shape=(32, 32, 3)))
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(0.001)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(0.001)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(0.001)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(0.001)))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', kernel_regularizer=l2(0.001)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform', kernel_regularizer=l2(0.001)))
	model.add(Dense(16, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# %%
 # run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY,validationX, validationY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, validationX, testX = prep_pixels(trainX,validationX, testX)
	# define model
	model = define_model_weight_decay()
 	# prepare iterator
	datagen = ImageDataGenerator()
	it_train = datagen.flow(trainX, trainY, batch_size=256)
	# fit model
	steps = int(trainX.shape[0] /256)
	history = model.fit(it_train, steps_per_epoch=steps, epochs=100, validation_data=(validationX, vlidationY), verbose=1)	# evaluate model
	_, acc = model.evaluate(validationX, validationY, verbose=1)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# Epoch 1/100
# 175/175 [==============================] - 6s 32ms/step - loss: 3.5964 - accuracy: 0.2165 - val_loss: 3.2988 - val_accuracy: 0.3136
# Epoch 2/100
# 175/175 [==============================] - 5s 28ms/step - loss: 3.1843 - accuracy: 0.3400 - val_loss: 3.0976 - val_accuracy: 0.3441
# Epoch 3/100
# 175/175 [==============================] - 5s 30ms/step - loss: 3.0148 - accuracy: 0.3872 - val_loss: 2.9572 - val_accuracy: 0.4051
# Epoch 4/100
# 175/175 [==============================] - 6s 32ms/step - loss: 2.8978 - accuracy: 0.4260 - val_loss: 2.9048 - val_accuracy: 0.4169
# Epoch 5/100
# 175/175 [==============================] - 5s 29ms/step - loss: 2.8178 - accuracy: 0.4478 - val_loss: 2.7793 - val_accuracy: 0.4563
# Epoch 6/100
# 175/175 [==============================] - 5s 30ms/step - loss: 2.7401 - accuracy: 0.4695 - val_loss: 2.7596 - val_accuracy: 0.4632
# Epoch 7/100
# 175/175 [==============================] - 5s 27ms/step - loss: 2.6722 - accuracy: 0.4918 - val_loss: 2.6659 - val_accuracy: 0.4844
# Epoch 8/100
# 175/175 [==============================] - 5s 30ms/step - loss: 2.6164 - accuracy: 0.5100 - val_loss: 2.5877 - val_accuracy: 0.5096
# Epoch 9/100
# 175/175 [==============================] - 6s 33ms/step - loss: 2.5637 - accuracy: 0.5244 - val_loss: 2.6109 - val_accuracy: 0.4953
# Epoch 10/100
# 175/175 [==============================] - 5s 31ms/step - loss: 2.5181 - accuracy: 0.5384 - val_loss: 2.5061 - val_accuracy: 0.5345
# Epoch 11/100
# 175/175 [==============================] - 5s 31ms/step - loss: 2.4563 - accuracy: 0.5555 - val_loss: 2.4659 - val_accuracy: 0.5471
# Epoch 12/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.4189 - accuracy: 0.5670 - val_loss: 2.4925 - val_accuracy: 0.5383
# Epoch 13/100
# 175/175 [==============================] - 5s 31ms/step - loss: 2.3730 - accuracy: 0.5782 - val_loss: 2.4168 - val_accuracy: 0.5593
# Epoch 14/100
# 175/175 [==============================] - 6s 32ms/step - loss: 2.3500 - accuracy: 0.5845 - val_loss: 2.3970 - val_accuracy: 0.5623
# Epoch 15/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.2915 - accuracy: 0.5998 - val_loss: 2.3777 - val_accuracy: 0.5705
# Epoch 16/100
# 175/175 [==============================] - 5s 31ms/step - loss: 2.2662 - accuracy: 0.6093 - val_loss: 2.3645 - val_accuracy: 0.5717
# Epoch 17/100
# 175/175 [==============================] - 5s 27ms/step - loss: 2.2320 - accuracy: 0.6202 - val_loss: 2.3316 - val_accuracy: 0.5772
# Epoch 18/100
# 175/175 [==============================] - 5s 27ms/step - loss: 2.1882 - accuracy: 0.6298 - val_loss: 2.3373 - val_accuracy: 0.5827
# Epoch 19/100
# 175/175 [==============================] - 5s 31ms/step - loss: 2.1557 - accuracy: 0.6399 - val_loss: 2.2902 - val_accuracy: 0.5903
# Epoch 20/100
# 175/175 [==============================] - 6s 32ms/step - loss: 2.1207 - accuracy: 0.6490 - val_loss: 2.2999 - val_accuracy: 0.5933
# Epoch 21/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.0979 - accuracy: 0.6558 - val_loss: 2.2490 - val_accuracy: 0.6023
# Epoch 22/100
# 175/175 [==============================] - 5s 27ms/step - loss: 2.0647 - accuracy: 0.6632 - val_loss: 2.2476 - val_accuracy: 0.6037
# Epoch 23/100
# 175/175 [==============================] - 5s 31ms/step - loss: 2.0271 - accuracy: 0.6731 - val_loss: 2.2412 - val_accuracy: 0.6052
# Epoch 24/100
# 175/175 [==============================] - 5s 28ms/step - loss: 2.0045 - accuracy: 0.6798 - val_loss: 2.1881 - val_accuracy: 0.6192
# Epoch 25/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.9738 - accuracy: 0.6878 - val_loss: 2.2074 - val_accuracy: 0.6117
# Epoch 26/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.9390 - accuracy: 0.6990 - val_loss: 2.2323 - val_accuracy: 0.6021
# Epoch 27/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.9152 - accuracy: 0.7049 - val_loss: 2.1817 - val_accuracy: 0.6225
# Epoch 28/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.8824 - accuracy: 0.7137 - val_loss: 2.1507 - val_accuracy: 0.6207
# Epoch 29/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.8562 - accuracy: 0.7224 - val_loss: 2.1782 - val_accuracy: 0.6260
# Epoch 30/100
# 175/175 [==============================] - 5s 30ms/step - loss: 1.8287 - accuracy: 0.7289 - val_loss: 2.2088 - val_accuracy: 0.6191
# Epoch 31/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.8128 - accuracy: 0.7311 - val_loss: 2.2017 - val_accuracy: 0.6160
# Epoch 32/100
# 175/175 [==============================] - 5s 29ms/step - loss: 1.7756 - accuracy: 0.7436 - val_loss: 2.1436 - val_accuracy: 0.6268
# Epoch 33/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.7432 - accuracy: 0.7510 - val_loss: 2.1972 - val_accuracy: 0.6199
# Epoch 34/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.7292 - accuracy: 0.7532 - val_loss: 2.1587 - val_accuracy: 0.6272
# Epoch 35/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.7089 - accuracy: 0.7593 - val_loss: 2.1448 - val_accuracy: 0.6331
# Epoch 36/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.6695 - accuracy: 0.7707 - val_loss: 2.2347 - val_accuracy: 0.6060
# Epoch 37/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.6406 - accuracy: 0.7798 - val_loss: 2.1760 - val_accuracy: 0.6309
# Epoch 38/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.6183 - accuracy: 0.7845 - val_loss: 2.1300 - val_accuracy: 0.6411
# Epoch 39/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.5858 - accuracy: 0.7947 - val_loss: 2.1807 - val_accuracy: 0.6347
# Epoch 40/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.5743 - accuracy: 0.7966 - val_loss: 2.1848 - val_accuracy: 0.6292
# Epoch 41/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.5344 - accuracy: 0.8084 - val_loss: 2.1648 - val_accuracy: 0.6397
# Epoch 42/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.5151 - accuracy: 0.8135 - val_loss: 2.1865 - val_accuracy: 0.6313
# Epoch 43/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.4881 - accuracy: 0.8225 - val_loss: 2.1851 - val_accuracy: 0.6384
# Epoch 44/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.4666 - accuracy: 0.8262 - val_loss: 2.1659 - val_accuracy: 0.6420
# Epoch 45/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.4374 - accuracy: 0.8360 - val_loss: 2.2090 - val_accuracy: 0.6268
# Epoch 46/100
# 175/175 [==============================] - 5s 29ms/step - loss: 1.4079 - accuracy: 0.8448 - val_loss: 2.2316 - val_accuracy: 0.6399
# Epoch 47/100
# 175/175 [==============================] - 5s 29ms/step - loss: 1.3826 - accuracy: 0.8525 - val_loss: 2.2735 - val_accuracy: 0.6260
# Epoch 48/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.3709 - accuracy: 0.8565 - val_loss: 2.2668 - val_accuracy: 0.6323
# Epoch 49/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.3410 - accuracy: 0.8636 - val_loss: 2.3166 - val_accuracy: 0.6359
# Epoch 50/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.3357 - accuracy: 0.8640 - val_loss: 2.2614 - val_accuracy: 0.6335
# Epoch 51/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.2959 - accuracy: 0.8766 - val_loss: 2.2937 - val_accuracy: 0.6424
# Epoch 52/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.2742 - accuracy: 0.8826 - val_loss: 2.3781 - val_accuracy: 0.6301
# Epoch 53/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.2591 - accuracy: 0.8885 - val_loss: 2.3342 - val_accuracy: 0.6433
# Epoch 54/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.2184 - accuracy: 0.9006 - val_loss: 2.4084 - val_accuracy: 0.6327
# Epoch 55/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.2016 - accuracy: 0.9046 - val_loss: 2.4018 - val_accuracy: 0.6372
# Epoch 56/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.1807 - accuracy: 0.9130 - val_loss: 2.4436 - val_accuracy: 0.6303
# Epoch 57/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.1644 - accuracy: 0.9174 - val_loss: 2.5083 - val_accuracy: 0.6224
# Epoch 58/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.1479 - accuracy: 0.9205 - val_loss: 2.5458 - val_accuracy: 0.6289
# Epoch 59/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.1319 - accuracy: 0.9252 - val_loss: 2.5629 - val_accuracy: 0.6229
# Epoch 60/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0921 - accuracy: 0.9381 - val_loss: 2.6506 - val_accuracy: 0.6269
# Epoch 61/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.0850 - accuracy: 0.9394 - val_loss: 2.6694 - val_accuracy: 0.6216
# Epoch 62/100
# 175/175 [==============================] - 5s 31ms/step - loss: 1.0742 - accuracy: 0.9423 - val_loss: 2.6789 - val_accuracy: 0.6304
# Epoch 63/100
# 175/175 [==============================] - 6s 31ms/step - loss: 1.0645 - accuracy: 0.9433 - val_loss: 2.6740 - val_accuracy: 0.6283
# Epoch 64/100
# 175/175 [==============================] - 6s 31ms/step - loss: 1.0431 - accuracy: 0.9500 - val_loss: 2.6813 - val_accuracy: 0.6324
# Epoch 65/100
# 175/175 [==============================] - 5s 27ms/step - loss: 1.0297 - accuracy: 0.9540 - val_loss: 2.6995 - val_accuracy: 0.6335
# Epoch 66/100
# 175/175 [==============================] - 5s 28ms/step - loss: 1.0018 - accuracy: 0.9642 - val_loss: 2.7747 - val_accuracy: 0.6308
# Epoch 67/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9775 - accuracy: 0.9720 - val_loss: 2.8098 - val_accuracy: 0.6392
# Epoch 68/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9606 - accuracy: 0.9771 - val_loss: 2.9115 - val_accuracy: 0.6248
# Epoch 69/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9496 - accuracy: 0.9793 - val_loss: 2.9031 - val_accuracy: 0.6359
# Epoch 70/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9382 - accuracy: 0.9822 - val_loss: 2.9178 - val_accuracy: 0.6309
# Epoch 71/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.9244 - accuracy: 0.9865 - val_loss: 2.9928 - val_accuracy: 0.6280
# Epoch 72/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9298 - accuracy: 0.9816 - val_loss: 3.0054 - val_accuracy: 0.6317
# Epoch 73/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.9172 - accuracy: 0.9853 - val_loss: 2.9844 - val_accuracy: 0.6335
# Epoch 74/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.9130 - accuracy: 0.9846 - val_loss: 3.0610 - val_accuracy: 0.6207
# Epoch 75/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.9000 - accuracy: 0.9887 - val_loss: 3.0573 - val_accuracy: 0.6324
# Epoch 76/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.8713 - accuracy: 0.9969 - val_loss: 3.0627 - val_accuracy: 0.6393
# Epoch 77/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.8610 - accuracy: 0.9984 - val_loss: 3.1061 - val_accuracy: 0.6339
# Epoch 78/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.8543 - accuracy: 0.9987 - val_loss: 3.1231 - val_accuracy: 0.6396
# Epoch 79/100
# 175/175 [==============================] - 5s 29ms/step - loss: 0.8455 - accuracy: 0.9993 - val_loss: 3.1404 - val_accuracy: 0.6377
# Epoch 80/100
# 175/175 [==============================] - 5s 30ms/step - loss: 0.8384 - accuracy: 0.9997 - val_loss: 3.1377 - val_accuracy: 0.6389
# Epoch 81/100
# 175/175 [==============================] - 6s 31ms/step - loss: 0.8332 - accuracy: 0.9997 - val_loss: 3.1705 - val_accuracy: 0.6369
# Epoch 82/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.8270 - accuracy: 0.9998 - val_loss: 3.1709 - val_accuracy: 0.6356
# Epoch 83/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.8213 - accuracy: 0.9999 - val_loss: 3.1654 - val_accuracy: 0.6393
# Epoch 84/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.8162 - accuracy: 0.9999 - val_loss: 3.1614 - val_accuracy: 0.6389
# Epoch 85/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.8118 - accuracy: 0.9999 - val_loss: 3.1715 - val_accuracy: 0.6385
# Epoch 86/100
# 175/175 [==============================] - 6s 32ms/step - loss: 0.8070 - accuracy: 1.0000 - val_loss: 3.1595 - val_accuracy: 0.6376
# Epoch 87/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.8019 - accuracy: 1.0000 - val_loss: 3.1571 - val_accuracy: 0.6407
# Epoch 88/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.7972 - accuracy: 1.0000 - val_loss: 3.1571 - val_accuracy: 0.6395
# Epoch 89/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.7924 - accuracy: 1.0000 - val_loss: 3.1601 - val_accuracy: 0.6403
# Epoch 90/100
# 175/175 [==============================] - 5s 27ms/step - loss: 0.7879 - accuracy: 1.0000 - val_loss: 3.1546 - val_accuracy: 0.6369
# Epoch 91/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.7836 - accuracy: 1.0000 - val_loss: 3.1359 - val_accuracy: 0.6376
# Epoch 92/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.7791 - accuracy: 1.0000 - val_loss: 3.1543 - val_accuracy: 0.6391
# Epoch 93/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.7748 - accuracy: 1.0000 - val_loss: 3.1364 - val_accuracy: 0.6353
# Epoch 94/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.7705 - accuracy: 1.0000 - val_loss: 3.1476 - val_accuracy: 0.6375
# Epoch 95/100
# 175/175 [==============================] - 5s 31ms/step - loss: 0.7661 - accuracy: 1.0000 - val_loss: 3.1389 - val_accuracy: 0.6392
# Epoch 96/100
# 175/175 [==============================] - 6s 32ms/step - loss: 0.7617 - accuracy: 1.0000 - val_loss: 3.1192 - val_accuracy: 0.6380
# Epoch 97/100
# 175/175 [==============================] - 6s 31ms/step - loss: 0.7575 - accuracy: 1.0000 - val_loss: 3.1242 - val_accuracy: 0.6381
# Epoch 98/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.7532 - accuracy: 1.0000 - val_loss: 3.0951 - val_accuracy: 0.6373
# Epoch 99/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.7491 - accuracy: 1.0000 - val_loss: 3.1032 - val_accuracy: 0.6411
# Epoch 100/100
# 175/175 [==============================] - 5s 28ms/step - loss: 0.7450 - accuracy: 1.0000 - val_loss: 3.0991 - val_accuracy: 0.6392
# 235/235 [==============================] - 1s 3ms/step - loss: 3.0991 - accuracy: 0.6392
# > 63.920

# %%
# using data augmentation

# %%
# no changes in model needed
def define_model_augmentation():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(16, activation='softmax'))
	# compile model
	opt = SGD(learning_rate=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# %%
# run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY,validationX, validationY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, validationX, testX = prep_pixels(trainX,validationX, testX)
	# define model
	model = define_model_augmentation()
	# create data generator
	datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
	# prepare iterator
	it_train = datagen.flow(trainX, trainY, batch_size=256)
	# fit model
	steps = int(trainX.shape[0] / 256)
	history = model.fit(it_train, steps_per_epoch=steps, epochs=100, validation_data=(validationX, vlidationY), verbose=1)	# evaluate model
	# evaluate model
	_, acc = model.evaluate(validationX, validationY, verbose=1)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# Epoch 1/100
# 175/175 [==============================] - 21s 113ms/step - loss: 2.4525 - accuracy: 0.1975 - val_loss: 2.2010 - val_accuracy: 0.2771
# Epoch 2/100
# 175/175 [==============================] - 19s 107ms/step - loss: 2.1465 - accuracy: 0.3041 - val_loss: 1.9595 - val_accuracy: 0.3691
# Epoch 3/100
# 175/175 [==============================] - 19s 107ms/step - loss: 1.9906 - accuracy: 0.3507 - val_loss: 1.8987 - val_accuracy: 0.3755
# Epoch 4/100
# 175/175 [==============================] - 19s 107ms/step - loss: 1.8696 - accuracy: 0.3899 - val_loss: 1.7234 - val_accuracy: 0.4323
# Epoch 5/100
# 175/175 [==============================] - 19s 107ms/step - loss: 1.7917 - accuracy: 0.4131 - val_loss: 1.6831 - val_accuracy: 0.4481
# Epoch 6/100
# 175/175 [==============================] - 20s 113ms/step - loss: 1.7462 - accuracy: 0.4246 - val_loss: 1.6093 - val_accuracy: 0.4681
# Epoch 7/100
# 175/175 [==============================] - 19s 107ms/step - loss: 1.6793 - accuracy: 0.4477 - val_loss: 1.5908 - val_accuracy: 0.4719
# Epoch 8/100
# 175/175 [==============================] - 20s 112ms/step - loss: 1.6353 - accuracy: 0.4635 - val_loss: 1.5363 - val_accuracy: 0.4896
# Epoch 9/100
# 175/175 [==============================] - 19s 109ms/step - loss: 1.6019 - accuracy: 0.4739 - val_loss: 1.5359 - val_accuracy: 0.4952
# Epoch 10/100
# 175/175 [==============================] - 20s 111ms/step - loss: 1.5676 - accuracy: 0.4858 - val_loss: 1.4870 - val_accuracy: 0.5115
# Epoch 11/100
# 175/175 [==============================] - 20s 111ms/step - loss: 1.5365 - accuracy: 0.4969 - val_loss: 1.5083 - val_accuracy: 0.5041
# Epoch 12/100
# 175/175 [==============================] - 19s 111ms/step - loss: 1.4966 - accuracy: 0.5110 - val_loss: 1.3963 - val_accuracy: 0.5416
# Epoch 13/100
# 175/175 [==============================] - 19s 107ms/step - loss: 1.4668 - accuracy: 0.5233 - val_loss: 1.4724 - val_accuracy: 0.5293
# Epoch 14/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.4455 - accuracy: 0.5264 - val_loss: 1.3614 - val_accuracy: 0.5571
# Epoch 15/100
# 175/175 [==============================] - 19s 107ms/step - loss: 1.4080 - accuracy: 0.5397 - val_loss: 1.3090 - val_accuracy: 0.5732
# Epoch 16/100
# 175/175 [==============================] - 20s 114ms/step - loss: 1.3821 - accuracy: 0.5509 - val_loss: 1.3108 - val_accuracy: 0.5731
# Epoch 17/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.3581 - accuracy: 0.5585 - val_loss: 1.2471 - val_accuracy: 0.5945
# Epoch 18/100
# 175/175 [==============================] - 19s 108ms/step - loss: 1.3450 - accuracy: 0.5621 - val_loss: 1.2791 - val_accuracy: 0.5801
# Epoch 19/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.3250 - accuracy: 0.5696 - val_loss: 1.3274 - val_accuracy: 0.5695
# Epoch 20/100
# 175/175 [==============================] - 19s 108ms/step - loss: 1.3071 - accuracy: 0.5726 - val_loss: 1.1954 - val_accuracy: 0.6111
# Epoch 21/100
# 175/175 [==============================] - 20s 114ms/step - loss: 1.2798 - accuracy: 0.5851 - val_loss: 1.2066 - val_accuracy: 0.6055
# Epoch 22/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.2668 - accuracy: 0.5869 - val_loss: 1.2138 - val_accuracy: 0.6109
# Epoch 23/100
# 175/175 [==============================] - 19s 107ms/step - loss: 1.2517 - accuracy: 0.5921 - val_loss: 1.1512 - val_accuracy: 0.6228
# Epoch 24/100
# 175/175 [==============================] - 19s 108ms/step - loss: 1.2381 - accuracy: 0.5974 - val_loss: 1.1829 - val_accuracy: 0.6103
# Epoch 25/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.2122 - accuracy: 0.6045 - val_loss: 1.1880 - val_accuracy: 0.6137
# Epoch 26/100
# 175/175 [==============================] - 20s 117ms/step - loss: 1.1986 - accuracy: 0.6075 - val_loss: 1.1236 - val_accuracy: 0.6311
# Epoch 27/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.1875 - accuracy: 0.6151 - val_loss: 1.1367 - val_accuracy: 0.6337
# Epoch 28/100
# 175/175 [==============================] - 19s 108ms/step - loss: 1.1753 - accuracy: 0.6184 - val_loss: 1.1504 - val_accuracy: 0.6245
# Epoch 29/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.1672 - accuracy: 0.6205 - val_loss: 1.1234 - val_accuracy: 0.6395
# Epoch 30/100
# 175/175 [==============================] - 19s 108ms/step - loss: 1.1401 - accuracy: 0.6270 - val_loss: 1.1512 - val_accuracy: 0.6319
# Epoch 31/100
# 175/175 [==============================] - 20s 116ms/step - loss: 1.1302 - accuracy: 0.6335 - val_loss: 1.0920 - val_accuracy: 0.6401
# Epoch 32/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.1131 - accuracy: 0.6360 - val_loss: 1.0713 - val_accuracy: 0.6572
# Epoch 33/100
# 175/175 [==============================] - 19s 108ms/step - loss: 1.1068 - accuracy: 0.6382 - val_loss: 1.0926 - val_accuracy: 0.6464
# Epoch 34/100
# 175/175 [==============================] - 19s 108ms/step - loss: 1.0924 - accuracy: 0.6431 - val_loss: 1.0350 - val_accuracy: 0.6652
# Epoch 35/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.0740 - accuracy: 0.6499 - val_loss: 1.0783 - val_accuracy: 0.6491
# Epoch 36/100
# 175/175 [==============================] - 20s 115ms/step - loss: 1.0750 - accuracy: 0.6514 - val_loss: 1.0603 - val_accuracy: 0.6577
# Epoch 37/100
# 175/175 [==============================] - 19s 111ms/step - loss: 1.0499 - accuracy: 0.6566 - val_loss: 1.0856 - val_accuracy: 0.6520
# Epoch 38/100
# 175/175 [==============================] - 19s 107ms/step - loss: 1.0490 - accuracy: 0.6580 - val_loss: 1.0398 - val_accuracy: 0.6631
# Epoch 39/100
# 175/175 [==============================] - 19s 111ms/step - loss: 1.0357 - accuracy: 0.6598 - val_loss: 0.9950 - val_accuracy: 0.6741
# Epoch 40/100
# 175/175 [==============================] - 19s 111ms/step - loss: 1.0278 - accuracy: 0.6631 - val_loss: 1.0264 - val_accuracy: 0.6660
# Epoch 41/100
# 175/175 [==============================] - 20s 117ms/step - loss: 1.0145 - accuracy: 0.6680 - val_loss: 0.9744 - val_accuracy: 0.6792
# Epoch 42/100
# 175/175 [==============================] - 19s 107ms/step - loss: 1.0102 - accuracy: 0.6705 - val_loss: 0.9995 - val_accuracy: 0.6740
# Epoch 43/100
# 175/175 [==============================] - 19s 110ms/step - loss: 1.0059 - accuracy: 0.6702 - val_loss: 1.0080 - val_accuracy: 0.6723
# Epoch 44/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.9947 - accuracy: 0.6736 - val_loss: 0.9556 - val_accuracy: 0.6937
# Epoch 45/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.9854 - accuracy: 0.6764 - val_loss: 1.0224 - val_accuracy: 0.6688
# Epoch 46/100
# 175/175 [==============================] - 20s 113ms/step - loss: 0.9762 - accuracy: 0.6811 - val_loss: 0.9729 - val_accuracy: 0.6855
# Epoch 47/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.9642 - accuracy: 0.6829 - val_loss: 0.9688 - val_accuracy: 0.6827
# Epoch 48/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.9586 - accuracy: 0.6852 - val_loss: 0.9775 - val_accuracy: 0.6816
# Epoch 49/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.9519 - accuracy: 0.6884 - val_loss: 0.9850 - val_accuracy: 0.6763
# Epoch 50/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.9436 - accuracy: 0.6897 - val_loss: 0.9680 - val_accuracy: 0.6900
# Epoch 51/100
# 175/175 [==============================] - 20s 113ms/step - loss: 0.9326 - accuracy: 0.6943 - val_loss: 0.9949 - val_accuracy: 0.6809
# Epoch 52/100
# 175/175 [==============================] - 19s 111ms/step - loss: 0.9207 - accuracy: 0.6960 - val_loss: 0.9494 - val_accuracy: 0.6889
# Epoch 53/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.9219 - accuracy: 0.6989 - val_loss: 0.9909 - val_accuracy: 0.6807
# Epoch 54/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.9070 - accuracy: 0.7006 - val_loss: 0.9521 - val_accuracy: 0.6955
# Epoch 55/100
# 175/175 [==============================] - 19s 111ms/step - loss: 0.9074 - accuracy: 0.7023 - val_loss: 0.9549 - val_accuracy: 0.6968
# Epoch 56/100
# 175/175 [==============================] - 20s 114ms/step - loss: 0.8927 - accuracy: 0.7092 - val_loss: 0.9044 - val_accuracy: 0.7100
# Epoch 57/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.8884 - accuracy: 0.7045 - val_loss: 0.9386 - val_accuracy: 0.6957
# Epoch 58/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.8832 - accuracy: 0.7131 - val_loss: 0.9111 - val_accuracy: 0.7052
# Epoch 59/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.8698 - accuracy: 0.7159 - val_loss: 0.9022 - val_accuracy: 0.7079
# Epoch 60/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.8622 - accuracy: 0.7167 - val_loss: 0.9372 - val_accuracy: 0.6981
# Epoch 61/100
# 175/175 [==============================] - 21s 117ms/step - loss: 0.8695 - accuracy: 0.7135 - val_loss: 0.9278 - val_accuracy: 0.7005
# Epoch 62/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.8531 - accuracy: 0.7188 - val_loss: 0.8901 - val_accuracy: 0.7139
# Epoch 63/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.8425 - accuracy: 0.7258 - val_loss: 0.9182 - val_accuracy: 0.7000
# Epoch 64/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.8420 - accuracy: 0.7243 - val_loss: 0.8736 - val_accuracy: 0.7187
# Epoch 65/100
# 175/175 [==============================] - 19s 111ms/step - loss: 0.8372 - accuracy: 0.7262 - val_loss: 0.8418 - val_accuracy: 0.7283
# Epoch 66/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.8301 - accuracy: 0.7262 - val_loss: 0.8640 - val_accuracy: 0.7204
# Epoch 67/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.8313 - accuracy: 0.7286 - val_loss: 0.9296 - val_accuracy: 0.7017
# Epoch 68/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.8243 - accuracy: 0.7300 - val_loss: 0.8572 - val_accuracy: 0.7252
# Epoch 69/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.8139 - accuracy: 0.7315 - val_loss: 0.9126 - val_accuracy: 0.7068
# Epoch 70/100
# 175/175 [==============================] - 20s 112ms/step - loss: 0.8096 - accuracy: 0.7355 - val_loss: 0.8617 - val_accuracy: 0.7243
# Epoch 71/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.7942 - accuracy: 0.7376 - val_loss: 0.8974 - val_accuracy: 0.7152
# Epoch 72/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.7986 - accuracy: 0.7386 - val_loss: 0.8873 - val_accuracy: 0.7172
# Epoch 73/100
# 175/175 [==============================] - 19s 111ms/step - loss: 0.7907 - accuracy: 0.7398 - val_loss: 0.8918 - val_accuracy: 0.7188
# Epoch 74/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.7903 - accuracy: 0.7391 - val_loss: 0.8838 - val_accuracy: 0.7203
# Epoch 75/100
# 175/175 [==============================] - 20s 117ms/step - loss: 0.7790 - accuracy: 0.7439 - val_loss: 0.9291 - val_accuracy: 0.7085
# Epoch 76/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.7732 - accuracy: 0.7471 - val_loss: 0.8582 - val_accuracy: 0.7284
# Epoch 77/100
# 175/175 [==============================] - 19s 111ms/step - loss: 0.7775 - accuracy: 0.7422 - val_loss: 0.8482 - val_accuracy: 0.7277
# Epoch 78/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.7662 - accuracy: 0.7485 - val_loss: 0.8873 - val_accuracy: 0.7157
# Epoch 79/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.7622 - accuracy: 0.7483 - val_loss: 0.8507 - val_accuracy: 0.7287
# Epoch 80/100
# 175/175 [==============================] - 20s 113ms/step - loss: 0.7549 - accuracy: 0.7525 - val_loss: 0.8638 - val_accuracy: 0.7256
# Epoch 81/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.7582 - accuracy: 0.7498 - val_loss: 0.8382 - val_accuracy: 0.7308
# Epoch 82/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.7480 - accuracy: 0.7517 - val_loss: 0.8350 - val_accuracy: 0.7323
# Epoch 83/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.7442 - accuracy: 0.7534 - val_loss: 0.8561 - val_accuracy: 0.7277
# Epoch 84/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.7456 - accuracy: 0.7527 - val_loss: 0.8336 - val_accuracy: 0.7333
# Epoch 85/100
# 175/175 [==============================] - 21s 117ms/step - loss: 0.7361 - accuracy: 0.7566 - val_loss: 0.8179 - val_accuracy: 0.7376
# Epoch 86/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.7327 - accuracy: 0.7572 - val_loss: 0.8688 - val_accuracy: 0.7257
# Epoch 87/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.7290 - accuracy: 0.7581 - val_loss: 0.8460 - val_accuracy: 0.7319
# Epoch 88/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.7254 - accuracy: 0.7604 - val_loss: 0.8599 - val_accuracy: 0.7287
# Epoch 89/100
# 175/175 [==============================] - 20s 113ms/step - loss: 0.7130 - accuracy: 0.7623 - val_loss: 0.8141 - val_accuracy: 0.7388
# Epoch 90/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.7125 - accuracy: 0.7632 - val_loss: 0.8446 - val_accuracy: 0.7265
# Epoch 91/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.7114 - accuracy: 0.7646 - val_loss: 0.8121 - val_accuracy: 0.7395
# Epoch 92/100
# 175/175 [==============================] - 19s 108ms/step - loss: 0.7027 - accuracy: 0.7683 - val_loss: 0.8185 - val_accuracy: 0.7364
# Epoch 93/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.7091 - accuracy: 0.7660 - val_loss: 0.8233 - val_accuracy: 0.7363
# Epoch 94/100
# 175/175 [==============================] - 20s 116ms/step - loss: 0.7007 - accuracy: 0.7678 - val_loss: 0.8334 - val_accuracy: 0.7352
# Epoch 95/100
# 175/175 [==============================] - 19s 107ms/step - loss: 0.6912 - accuracy: 0.7714 - val_loss: 0.8478 - val_accuracy: 0.7335
# Epoch 96/100
# 175/175 [==============================] - 19s 111ms/step - loss: 0.6903 - accuracy: 0.7692 - val_loss: 0.8432 - val_accuracy: 0.7351
# Epoch 97/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.6867 - accuracy: 0.7705 - val_loss: 0.8420 - val_accuracy: 0.7331
# Epoch 98/100
# 175/175 [==============================] - 19s 110ms/step - loss: 0.6888 - accuracy: 0.7702 - val_loss: 0.8216 - val_accuracy: 0.7389
# Epoch 99/100
# 175/175 [==============================] - 20s 116ms/step - loss: 0.6766 - accuracy: 0.7750 - val_loss: 0.8196 - val_accuracy: 0.7431
# Epoch 100/100
# 175/175 [==============================] - 19s 111ms/step - loss: 0.6736 - accuracy: 0.7789 - val_loss: 0.7978 - val_accuracy: 0.7505
# 235/235 [==============================] - 1s 4ms/step - loss: 0.7978 - accuracy: 0.7505
# > 75.053

# %%
# define cnn model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
	model.add(BatchNormalization())
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.3))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.4))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(BatchNormalization())
	model.add(Dropout(0.5))
	model.add(Dense(16, activation='softmax'))
 	# compile model
	opt = SGD(learning_rate=0.001, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
	return model

# %%
# run the test harness for evaluating a model
def run_test_harness():
	# load dataset
	trainX, trainY,validationX, validationY, testX, testY = load_dataset()
	# prepare pixel data
	trainX, validationX, testX = prep_pixels(trainX,validationX, testX)
	# define model
	model = define_model()
	# create data generator
	datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
	# prepare iterator
	it_train = datagen.flow(trainX, trainY, batch_size=256)
	# fit model
	steps = int(trainX.shape[0] /256)
	history = model.fit(it_train, steps_per_epoch=steps, epochs=100, validation_data=(validationX, vlidationY), verbose=1)
	# evaluate model
	_, acc = model.evaluate(validationX, validationY, verbose=1)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(history)

# %%
# entry point, run the test harness
run_test_harness()
# Out:
# Epoch 1/100
# 175/175 [==============================] - 21s 112ms/step - loss: 3.1576 - accuracy: 0.1524 - val_loss: 2.7440 - val_accuracy: 0.1417
# Epoch 2/100
# 175/175 [==============================] - 19s 109ms/step - loss: 2.5034 - accuracy: 0.2402 - val_loss: 2.2876 - val_accuracy: 0.2456
# Epoch 3/100
# 175/175 [==============================] - 21s 118ms/step - loss: 2.3130 - accuracy: 0.2745 - val_loss: 1.9821 - val_accuracy: 0.3468
# Epoch 4/100
# 175/175 [==============================] - 20s 113ms/step - loss: 2.2065 - accuracy: 0.2987 - val_loss: 1.9060 - val_accuracy: 0.3789
# Epoch 5/100
# 175/175 [==============================] - 20s 111ms/step - loss: 2.1175 - accuracy: 0.3184 - val_loss: 1.8712 - val_accuracy: 0.3912
# Epoch 6/100
# 175/175 [==============================] - 20s 114ms/step - loss: 2.0488 - accuracy: 0.3356 - val_loss: 1.8473 - val_accuracy: 0.3952
# Epoch 7/100
#   1/175 [..............................] - ETA: 22s - loss: 1.9636 - accuracy: 0.3672
